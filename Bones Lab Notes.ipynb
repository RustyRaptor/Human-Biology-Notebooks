# %%
from PyPDF2 import PdfReader, PdfWriter

def append_pdfs(input_pdf1, input_pdf2, output_pdf):
    # Create PdfReader objects for both input PDFs
    pdf1 = PdfReader(input_pdf1)
    pdf2 = PdfReader(input_pdf2)

    # Create a PdfFileWriter object for the output PDF
    pdf_writer = PdfWriter()

    # Append pages from the first PDF
    for page_num in range(len(pdf1.pages)):
        pdf_writer.add_page(pdf1.pages[page_num])

    # Append pages from the second PDF
    for page_num in range(len(pdf2.pages)):
        pdf_writer.add_page(pdf2.pages[page_num])

    # Write the combined PDF to the output file
    with open(output_pdf, 'wb') as output_file:
        pdf_writer.write(output_file)
        
def compile_lab_report(first_page, appendix_a, appendix_b, output_pdf):
        # Create PdfReader objects for all input PDFs
        pdf1 = PdfReader(first_page)
        pdf2 = PdfReader(appendix_a)
        pdf3 = PdfReader(appendix_b)
        
        # Create a PdfFileWriter object for the output PDF
        pdf_writer = PdfWriter()
        
        # Append pages from the first PDF
        for page_num in range(len(pdf1.pages)):
                pdf_writer.add_page(pdf1.pages[page_num])
        
        # Append pages from the second PDF
        for page_num in range(len(pdf2.pages)):
                pdf_writer.add_page(pdf2.pages[page_num])
        
        # Append pages from the third PDF
        for page_num in range(len(pdf3.pages)):
                pdf_writer.add_page(pdf3.pages[page_num])
        
        # Write the combined PDF to the output file
        with open(output_pdf, 'wb') as output_file:
                pdf_writer.write(output_file)
        

# compile lab report
compile_lab_report(
        './Evolution of Resistance to Antibiotics in Bacteria Lab Report.pdf',
        './AppendixA.pdf',
        './AppendixB.pdf',
        'compiled_lab_report.pdf'
)

# %% [markdown]
# # Forensic Science Lab Report
# - Ziad Arafat
# - 02/27/2024
# - New Mexico State University
#
# ## Abstract
# In lab, we inspected some plastic bones that are fictitiously linked to missing persons cases and used our knowlege of forensic anthropology to formulate a hypothesis about which bones belong to which missing person case and then using genetic data from the bones and the missing persons to test the hypothesis.
#
# ## Methodology
# 1. Record observations about the bones to identify probably attributes of the person.
#    1. Included attributes
#       1. Sex
#          1. pelvis structure
#       2. Ethnicity
#          1. Skull structure
#       3. Height
#          1. Length of the femur
# 2. Use these observations to make a hypothesis about who is the likely associated missing person on the chart.
# 3. Test our hypothesis by comparing the DNA of the bones with the known DNA of the missing person using a tool called NEBCutter2.0
#
# ## Bones Lab Observations
#
# - Bones Group: A
# - Pelvis
#   -  Pubic Angle
#      - less than 90 degrees
#   - Sciatic Notch: Broad
#   - Inlet shape: Broad
#   - **Likely female.**
# - Skull
#   - No overbite
#   - Facial profile: round.
#   - Nasal Sill: present
#   - Nasal opening: narrow.
#   - Nasal Bridge: not high bridged
#   - Cheek bones: high
#   - **Likely Asian**
# - Femur
#   - Length: approx 40 cm
#   - estimated height (cm): 152.9 cm
#     - Converted to inches: $\approx 5.01$ inches
#     - **Closest heights on chart:**
#       - 4'11"
#       - 5'0"
# - Most likely missing person based on observations:
#   - **LT**
#     - Chinese Female with a height of 4'11" most closely matches our observations.
#
# ## Hypothesis
# - Our hypothesis is that the bones from group "A" belong to missing person "LT".
#
# ## DNA Tests using NEBCutter 3
# +----------------------------------------------+-----+---------------------------------------+--------------------------------------+
# |  			DNA 			FRAGMENTS OF KNOWN SIZE -   1kb ladder 		 |     |  			DNA 			FRAGMENTS OF BONE SET _________ 		 |  			DNA 			FRAGMENTS OF PERSON __________ 		 |
# +----------------------------------------------+-----+---------------------------------------+--------------------------------------+
# |  			                                            |  			   |  			                                     |  			                                    |
# |   			                                           |   			 		 |   			 		                                   |   			 		                                  |
# |  			                                            |     |                                       |                                      |
# |  			10000                                       |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			8000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			6000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			5000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			4000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			3000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			2000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			1500                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			1000                                        |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			                                           |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |  			500                                         |     |                                       |                                      |
# |  			                                            |     |                                       |                                      |
# |   			 		                                          |     |                                       |                                      |
# +----------------------------------------------+-----+---------------------------------------+--------------------------------------+
#
# ## Appendix A (Raw Data)
#
# ### Bone Set A NEBCutter Gel Render
# ![Bone Set A Gel Render](/home/doge/Documents/src/Human-Biology-Notebooks/Bone_Set_A.png)
#
# ### Missing Person LT NEBCutter Gel Render
# ![Missing Person LT Gel Render](/home/doge/Documents/src/Human-Biology-Notebooks/Missing_Person_LT.png)
#
# ## Appendix B (Calculations)

# %%
# Calculations used to get height from femur length

femur_length = 40 # cm

def height_female_from_femur(femur_length):
    return 2.47 * femur_length + 54.1

def cm_to_inches(cm):
    return cm / 30.48

estimated_height = height_female_from_femur(femur_length)

print(estimated_height, "cm")

print(cm_to_inches(estimated_height), "inches")
# Out:
# 152.9 cm
# 5.016404199475065 inches
