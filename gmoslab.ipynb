# %% [markdown]
# # Genetically Modified Organisms Lab Report
# - Ziad Arafat
#
# Write a 1 page (typed, double-spaced) essay about genetically modified foods that
# addresses the following questions:
# -What are genetically modified organisms? What foods are allowed to be produced from
# genetically modified organisms?
# -What are some of the benefits and some of the concerns about the use of genetically
# modified organisms in food production
# -Use APA 7 citation style to cite your sources and in-text citations
#
# ## Essay
#
# 1. According to Whitman (2000) GMOs are crops modified using molecular biology techniques usually to get desired traits such as resistance to pests, diseases, or herbicides (Whitman, 2000). Whitman tells us that genetic engineering is more efficient than traditional breeding methods because it can introduce desired traits from unrelated species instantly (Whitman, 2000).
# 2. From Whitman's article, we learn that different countries have different regulations on GMOs (Whitman, 2000). In Whitman's article we see that this is both in what crops are allowed to be grown and what foods are allowed to be produced from GMOs (Whitman, 2000). Whitman tells us that in the United States, foods produced by GMs are regulated by the FDA while crops are regulated by the USDA (for agricultural factors) and the EPA (for environmental factors) (Whitman, 2000).
# 3. Whitman lists many benefits of GMs including Pest resistance, herbicide tolerance, disease resistance, cold tolerance, drought tolerance, nutrition, and pharmaceuticals (Whitman, 2000). Whitman discusses some critcisms as well such as unintended harm to other organisms, reduced effectiveness of pesticides, and gene transfer to non-target species (Whitman, 2000). Whitman also discusses the potential for allergens and toxins to be introduced into foods and the uncertain effects on human health (Whitman, 2000). However Whitman also mentions that scientists have not found any evidence of harm to humans from GM foods (Whitman, 2000).
#
# ## Hypothesis
#
# 1. Genetically modified crop plants are a large part of food production in the US today.
#
# ## Predicted Results
#
# 1. More than 50% of the ingredients of the products in the dataset are genetically modified.
#
# ### What is niacin
#
# 1. Niacin is a form of vitamin B3. It is found in many foods including yeast, meat, fish, milk, eggs, green vegetables, and cereal grains. Some cereal grains are fortified with niacin. It is also available as a supplement.
#
# ### What is tocoferol
#
# 1. Tocopherols are a class of organic chemical compounds (more precisely, various methylated phenols), many of which have vitamin E activity. Because the vitamin activity was first identified in 1936 from a dietary fertility factor in rats, it was given the name "tocopherol" from the Greek words "τόκος" [tókos, birth], and "φέρειν", [phérein, to bear or carry] meaning in sum "to carry a pregnancy," with the ending "-ol" signifying its status as a chemical alcohol.
# 2. Tocopherol is extracted from vegetable oils, such as soybean oil. It is also found in foods such as nuts, seeds, and leafy green vegetables, and is commonly used as a dietary supplement.
#
# ### What is calcium carbonate
#
# 1. Calcium carbonate is a chemical compound with the formula CaCO3. It is a common substance found in rocks as the minerals calcite and aragonite (most notably as limestone, which is a type of sedimentary rock consisting mainly of calcite) and is the main component of pearls and the shells of marine organisms, snails, and eggs. Calcium carbonate is the active ingredient in agricultural lime and is created when calcium ions in hard water react with carbonate ions to create limescale. It is medicinally used as a calcium supplement or as an antacid, but excessive consumption can be hazardous.
#
# ## Discussion
#
# Discussion
# The Discussion must contain the following components:
# -a statement of the hypothesis of the experiment (properly paraphrased and cited)
# -a comparison of the predicted results to the observed results listed in Table 11-3.
# -a conclusion: a statement which evaluates the hypothesis of the experiment, indicating
# whether the hypothesis is supported by the gel results or whether the results do not
# support the hypothesis and the hypothesis must be rejected.
# -explain how the gel electrophoresis results led to your conclusion. This is the most
# important part of the lab report because you are using evidence to support your conclusion
# that the hypothesis either is or is not supported by the experimental results.
#
# 1. Our hypothesis is that genetically modified crop plants are a large part of food production in the US today. The predicted results are that more than 50% of the ingredients of the products in the dataset are genetically modified. The observed results are that 0% of the ingredients in the dataset are genetically modified. This leads us to conclude that the hypothesis is not supported by the gel results and must be rejected. The gel electrophoresis results show that none of the ingredients in the dataset are genetically modified. This is evidence that genetically modified crop plants are not a large part of food production in the US today.
#
# ## References
#
# 1. Whitman, D. B. (2000, April). Genetically modified foods: Harmful or helpful? CSA Discovery Guides. <http://www.csa.com/discoveryguides/discoveryguides-main.php>

# %%
# Data Recording

quaker_yellow_cornmeal = {
        "degerminated yellow cornmeal": True,
        "niacin": True,
        "reduced iron": True,
        "Mononitrate": True,
        "Riboflavin": True,
        "follic acid": True,
        "one of the B vitamins": True,
}

roasted_nut_crunch = {
        "almonds": True,
        "roasted peanuts": True,
        "sugar": True,
        "sunflower seeds": True,
        "Corn Syrup": True,
        "Corn Flour": True,
        "Salt": False,
        "Corn Oil": True,
        "Calcium Carbonate": False,
        "Color": False,
        "Tocoferol": True
}

triscuit_biscuits = {
        "Whole wheat": True,
        "soybean": True,
        "palm oil": True,
        "salt": False
}

fritos = {
        "whole corn": True,
        "Corn oil": True,
        "Salt": False
}

products = {
        "triscuit_biscuits": False,
        "roasted_nut_crunch": False,
        "quaker_yellow_cornmeal": True,
        "fritos": True
}

# Create a MS Word table for each product. Make the True ingredients bold and the False ingredients italicized.

from docx import Document

def create_table(product, ingredients):
        doc = Document()
        doc.add_heading(product, 0)
        table = doc.add_table(rows=1, cols=2)
        table.style = 'Table Grid'
        table.autofit = True
        hdr_cells = table.rows[0].cells
        hdr_cells[0].text = 'Ingredient'
        hdr_cells[1].text = 'Present'
        for ingredient, present in ingredients.items():
                row_cells = table.add_row().cells
                row_cells[0].text = ingredient
                row_cells[1].text = str(present)
                if present:
                        row_cells[0].paragraphs[0].runs[0].bold = True
                else:
                        row_cells[0].paragraphs[0].runs[0].italic = True
        return doc

products_list = [
        triscuit_biscuits,
        roasted_nut_crunch,
        quaker_yellow_cornmeal,
        fritos
]

docs = []

for key, product in enumerate(products_list):
        docs.append(create_table(list(products.keys())[key], product))

# %% [markdown]
# Subspecies 1|Subspecies 2|Trial 1|Trial 2|Trial 3|Average
# |---|---|---|---|---|---|
# schweinfurthii|schweinfurthii|1.47|1.77|1.77|1.67
# verus|verus|4.41|6.18|7.06|5.88
# troglodytes|troglodytes|1.47|1.18|1.47|1.38
# schweinfurthii|verus|10.59|9.41|9.73|9.91
# schweinfurthii|troglodytes|6.19|4.72|5.6|5.51
# verus|troglodytes|11.47|11.47|11.47|11.47

# %%
# Comparison of chimp subspecies

schweinfurthii_total = 339
verus_total = 340
troglodytes_total = 339

chimp_subspecies_ = {
        ("schweinfurthii", "schweinfurthii"): {
                frozenset(("chimp13s", "chimp10s")): 5 / 339 * 100,
                frozenset(("chimp13s", "chimp11s")): 6 / 339 * 100,
                frozenset(("chimp13s", "chimp12s")): 6 / 339 * 100,
        },
        ("verus", "verus"): {
                frozenset(("chimp1v", "chimp2v")): 15 / 340 * 100,
                frozenset(("chimp1v", "chimp3v")): 21 / 340 * 100,
                frozenset(("chimp1v", "chimp4v")): 24 / 340 * 100,
        },
        ("troglodytes", "troglodytes"): {
                frozenset(("chimp6t", "chimp8t")): 5 / 339 * 100,
                frozenset(("chimp6t", "chimp9t")): 4 / 339 * 100,
                frozenset(("chimp8t", "chimp9t")): 5 / 339 * 100,
        },
        ("schweinfurthii", "verus"): {
                frozenset(("chimp13s", "chimp1v")): 36 / 340 * 100,
                frozenset(("chimp13s", "chimp2v")): 32 / 340 * 100,
                frozenset(("chimp13s", "chimp3v")): 33 / 339 * 100,
        },
        ("schweinfurthii", "troglodytes"): {
                frozenset(("chimp13s", "chimp6t")): 21 / 339 * 100,
                frozenset(("chimp13s", "chimp8t")): 16 / 339 * 100,
                frozenset(("chimp13s", "chimp9t")): 19 / 339 * 100,
        },
        ("verus", "troglodytes"): {
                frozenset(("chimp1v", "chimp6t")): 39 / 340 * 100,
                frozenset(("chimp1v", "chimp8t")): 39 / 340 * 100,
                frozenset(("chimp1v", "chimp9t")): 39 / 340 * 100,
        }
}

def matrix_to_markdown_table(matrix, header):
        table = []
        table.append("|".join(header))
        header_separator = "|" + "|".join(["---" for _ in header]) + "|"
        table.append(header_separator)
        for row in matrix:
                table.append("|".join([str(cell) for cell in row]))
        return "\n".join(table)

def extract_data_into_matrix(data):
        table = []
        for subspecies, comparisons in data.items():
                comparisons_value_list = list(comparisons.values())
                trial_1 = round(comparisons_value_list[0], 2)
                trial_2 = round(comparisons_value_list[1], 2)
                trial_3 = round(comparisons_value_list[2], 2)
                average = round(sum(comparisons_value_list) / len(comparisons_value_list), 2)
                
                table.append([trial_1, trial_2, trial_3, average])
        return table
        




header = ["Subspecies 1", "Subspecies 2", "Trial 1", "Trial 2", "Trial 3", "Average"]
table = matrix_to_markdown_table(
        extract_data_into_matrix(chimp_subspecies_), 
        header
)

print(table)
# Out:
# Subspecies 1|Subspecies 2|Trial 1|Trial 2|Trial 3|Average
# |---|---|---|---|---|---|
# 1.47|1.77|1.77|1.67
# 4.41|6.18|7.06|5.88
# 1.47|1.18|1.47|1.38
# 10.59|9.41|9.73|9.91
# 6.19|4.72|5.6|5.51
# 11.47|11.47|11.47|11.47

# %% [markdown]
# # Evidence of subspecies
#
# 1. The evidence is that comparisons between same species show a lower percentage of difference than comparisons between different species. This is evidence that the two groups are subspecies of the same species.
# 2. Another piece of evidence is that the phylogenetic tree shows that same species chimps are grouped together.

# %% [markdown]
# # Hypothesis
#
# In humans, race is a social construct and not a biological one.
#
# # Predicted Results
#
# When comparing 3 groups of humans, the genetic differences between individuals in different groups will be less than or equal to the genetic differences between individuals in the same group.

# %%
# Comparison of human "subspecies"

human_subspecies_ = {
        ("african", "african"): {
                frozenset(("Africa 1", "Africa 2")): 9/265 * 100,
                frozenset(("Africa 1", "Africa 3")): 2/265 * 100,
                frozenset(("Africa 2", "Africa 3")): 11/265 * 100,
        },
        ("european", "european"): {
                frozenset(("Europe 1", "Europe 2")): 5/265 * 100,
                frozenset(("Europe 1", "Europe 3")): 6/265 * 100,
                frozenset(("Europe 2", "Europe 3")): 9/265 * 100,
        },
        ("asian", "asian"): {
                frozenset(("Asia 1", "Asia 2")): 7/265 * 100,
                frozenset(("Asia 1", "Asia 3")): 6/265 * 100,
                frozenset(("Asia 2", "Asia 3")): 9/265 * 100,
        },
        ("african", "european"): {
                frozenset(("Africa 1", "Europe 1")): 3/265 * 100,
                frozenset(("Africa 1", "Europe 2")): 6/265 * 100,
                frozenset(("Africa 1", "Europe 3")): 3/265 * 100,
        },
        ("african", "asian"): {
                frozenset(("Africa 1", "Asia 1")): 2/265 * 100,
                frozenset(("Africa 1", "Asia 2")): 5/265 * 100,
                frozenset(("Africa 1", "Asia 3")): 4/265 * 100,
        },
        ("european", "asian"): {
                frozenset(("Europe 1", "Asia 1")): 5/265 * 100,
                frozenset(("Europe 1", "Asia 2")): 6/265 * 100,
                frozenset(("Europe 1", "Asia 3")): 7/265 * 100,
        }
}



# convert matrix to output that can be pasted into a Word table
# Example noting the tabs in between entries and alignment
"""
1.47	1.77	1.77	1.67
4.41	6.18	7.06	5.88
1.47	1.18	1.47	1.38
10.59	9.41	9.73	9.91
6.19	4.72	5.6	5.51
11.47	11.47	11.47	11.47
"""
def matrix_to_msword_table(matrix):
        table = []
        for row in matrix:
                table.append("\t".join([str(cell) for cell in row]))
        return "\n".join(table)


header = ["Trial 1", "Trial 2", "Trial 3", "Average"]
table = matrix_to_markdown_table(
        extract_data_into_matrix(human_subspecies_)[2:5],
        header
)

table_word = matrix_to_msword_table(
        extract_data_into_matrix(human_subspecies_)
)

with open("human_subspecies_table.txt", "w") as file:
        file.write(table_word)
